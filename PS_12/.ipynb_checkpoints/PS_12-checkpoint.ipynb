# %%
import pandas as pd

# %%
col=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','target']
df=pd.read_csv('adult.csv')
df.columns=col
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df['native-country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
usa=df[df['native-country']==' United-States']
usa
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 4       37            Private  284582      Masters             14
# 6       52   Self-emp-not-inc  209642      HS-grad              9
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
cuba=df[df['native-country']==" Cuba"]
cuba
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 3       28            Private  338409   Bachelors             13
# 80      52            Private  276515   Bachelors             13
# 637     47       Self-emp-inc  248145     5th-6th              3
# 700     31            Private  243605   Bachelors             13
# 1236    41   Self-emp-not-inc  209344     HS-grad              9
# ...    ...                ...     ...         ...            ...
# 30840   37            Private  238433     1st-4th              2
# 30891   52            Private  222646        12th              8
# 30905   39   Self-emp-not-inc  251323         9th              5
# 31148   52       Self-emp-inc  230767   Bachelors             13
# 31906   48            Private  379883     Masters             14
#
#             marital-status          occupation     relationship    race  \
# 3       Married-civ-spouse      Prof-specialty             Wife   Black
# ...

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
male=df[df['sex']==' Male']
male
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 6       52   Self-emp-not-inc  209642        HS-grad              9
# 8       42            Private  159449      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 32552   32            Private  116138        Masters             14
# 32553   53            Private  321865        Masters             14
# 32554   22            Private  310152   Some-college             10
# 32556   40            Private  154374        HS-grad              9
# 32558   22            Private  201490        HS-grad              9
#
#             marital-status          occupation    relationship  \
# 0       Married-civ-spouse     Exec-managerial         Husband
# ...

# %%
female=df[df['sex']==' Female']
female
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 3       28        Private  338409      Bachelors             13
# 4       37        Private  284582        Masters             14
# 5       49        Private  160187            9th              5
# 7       31        Private   45781        Masters             14
# 11      23        Private  122272      Bachelors             13
# ...    ...            ...     ...            ...            ...
# 32545   37        Private  198216     Assoc-acdm             12
# 32548   43      State-gov  255835   Some-college             10
# 32555   27        Private  257302     Assoc-acdm             12
# 32557   58        Private  151910        HS-grad              9
# 32559   52   Self-emp-inc  287927        HS-grad              9
#
#                marital-status        occupation     relationship    race  \
# 3          Married-civ-spouse    Prof-specialty             Wife   Black
# ...

# %%
df['race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
white=df[df['race']==" White"]
white
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 4       37            Private  284582      Masters             14
# 6       52   Self-emp-not-inc  209642      HS-grad              9
# 7       31            Private   45781      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
black=df[df['race']==" Black"]
black
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 2       53   Private  234721           11th              7
# 3       28   Private  338409      Bachelors             13
# 5       49   Private  160187            9th              5
# 9       37   Private  280464   Some-college             10
# 12      32   Private  205019     Assoc-acdm             12
# ...    ...       ...     ...            ...            ...
# 32520   33   Private  273243        HS-grad              9
# 32534   22   Private  325033           12th              8
# 32536   30   Private  345898        HS-grad              9
# 32537   38   Private  139180      Bachelors             13
# 32540   41         ?  202822        HS-grad              9
#
#                marital-status          occupation    relationship    race  \
# 2          Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3          Married-civ-spouse      Prof-specialty            Wife   Black
# ...

# %%
merge1=pd.concat([white,black])
merge1
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       50   Self-emp-not-inc   83311   Bachelors             13
# 1       38            Private  215646     HS-grad              9
# 4       37            Private  284582     Masters             14
# 6       52   Self-emp-not-inc  209642     HS-grad              9
# 7       31            Private   45781     Masters             14
# ...    ...                ...     ...         ...            ...
# 32520   33            Private  273243     HS-grad              9
# 32534   22            Private  325033        12th              8
# 32536   30            Private  345898     HS-grad              9
# 32537   38            Private  139180   Bachelors             13
# 32540   41                  ?  202822     HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
sorted=df.sort_values('age')
sorted
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 15541   17                  ?  112942           10th              6
# 26089   17   Self-emp-not-inc  174120           12th              8
# 22495   17            Private  118792           11th              7
# 22856   17          Local-gov  340043           12th              8
# 12980   17                  ?  262196           10th              6
# ...    ...                ...     ...            ...            ...
# 11511   90            Private   87285        HS-grad              9
# 12450   90                  ?  225063   Some-college             10
# 6623    90            Private  313986           11th              7
# 18831   90            Private  115306        Masters             14
# 8805    90            Private   87372    Prof-school             15
#
#             marital-status          occupation relationship  \
# 15541        Never-married                   ?    Own-child
# ...

# %%
transposed=df.T
transposed
# Out:
#                               0                   1                    2      \
# age                              50                  38                   53
# workclass          Self-emp-not-inc             Private              Private
# fnlwgt                        83311              215646               234721
# education                 Bachelors             HS-grad                 11th
# education-num                    13                   9                    7
# marital-status   Married-civ-spouse            Divorced   Married-civ-spouse
# occupation          Exec-managerial   Handlers-cleaners    Handlers-cleaners
# relationship                Husband       Not-in-family              Husband
# race                          White               White                Black
# sex                            Male                Male                 Male
# capital-gain                      0                   0                    0
# ...

# %%
melting=pd.melt(df,id_vars=["education","age"],var_name="Metrics",value_name="Values")
melting
# Out:
#           education  age    Metrics             Values
# 0         Bachelors   50  workclass   Self-emp-not-inc
# 1           HS-grad   38  workclass            Private
# 2              11th   53  workclass            Private
# 3         Bachelors   28  workclass            Private
# 4           Masters   37  workclass            Private
# ...             ...  ...        ...                ...
# 423275   Assoc-acdm   27     target              <=50K
# 423276      HS-grad   40     target               >50K
# 423277      HS-grad   58     target              <=50K
# 423278      HS-grad   22     target              <=50K
# 423279      HS-grad   52     target               >50K
#
# [423280 rows x 4 columns]

# %%
casting=pd.pivot_table(df,index=["age","target"],values="hours-per-week")
casting
# Out:
#             hours-per-week
# age target
# 17   <=50K       21.367089
# 18   <=50K       25.912727
# 19   <=50K       30.623944
#      >50K        50.000000
# 20   <=50K       32.280212
# ...                    ...
# 86   <=50K       40.000000
# 87   <=50K        2.000000
# 88   <=50K       40.000000
# 90   <=50K       34.742857
#      >50K        45.875000
#
# [138 rows x 1 columns]
